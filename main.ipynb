# %%
import subprocess, textwrap, operator, base64
from langgraph.graph import END, START, StateGraph
from langgraph.types import Send, interrupt, Command
from langgraph.checkpoint.memory import InMemorySaver
from langchain.chat_models import init_chat_model
from typing import TypedDict
from openai import OpenAI
from typing_extensions import Annotated

memory = InMemorySaver()

llm = init_chat_model("openai:gpt-5-nano")


class State(TypedDict):
    video_file: str
    audio_file: str
    transcription: str
    summaries: Annotated[list[str], operator.add]
    thumbnail_prompts: Annotated[list[str], operator.add]
    thumbnail_sketches: Annotated[list[str], operator.add]
    final_summary: str
    user_feedback: str
    chosen_prompt: str

# %%
def extract_audio(state: State):
    output_file = state["video_file"].replace("mp4", "mp3")
    command = [
        "ffmpeg",
        "-i",
        state["video_file"],
        "-filter:a",
        "atempo=2.0",
        "-y",
        output_file
    ]
    subprocess.run(command)
    return {
        "audio_file": output_file
    }

def transcribe_audio(state: State):
    client = OpenAI()
    with open(state["audio_file"], "rb") as audio_file:
        transcription = client.audio.transcriptions.create(
            model="whisper-1",
            response_format="text",
            file=audio_file,
            # language="en",
            # prompt="to give the model some hints for audio file"
        )
        return {
            "transcription": transcription
        }

def dispatch_summarizers(state: State):
    transcription = state["transcription"]
    chunks = []
    for i, chunk in enumerate(textwrap.wrap(transcription, 500)):
        chunks.append({"id": i + 1, "chunk": chunk})
    return [Send("summarize_chunk", chunk) for chunk in chunks]

def summarize_chunk(chunk_item):
    chunk_id = chunk_item["id"]
    chunk = chunk_item["chunk"]
    # print(f"Summarizing chunk id: {chunk_id} chunk: {chunk[:100]}\n\n====\n\n")

    response = llm.invoke(
        f"""
        Please summarize the following text.

        Text: {chunk}
        """
    )
    summary = f"[Chunk {chunk_id}] {response.content}"
    return {
        "summaries": [summary]
    }

def mega_summary(state: State):
    all_summaries = "\n".join(state["summaries"])
    prompt = f"""
        You are given multiple summaries of different chunks from a video transcription.

        Please create a comprehensive final summary that combines all the key points.

        Individual summaries:

        {all_summaries}
    """
    response = llm.invoke(prompt)

    return {
        "final_summary": response.content
    }

def dispatch_artists(state: State):
    return [
        Send("generate_thumbnails", {"id": i, "summary": state["final_summary"]}) for i in [1, 2, 3]
    ]

def generate_thumbnails(args):
    concept_id = args["id"]
    summary = args["summary"]
    prompt = f"""
        Based on this video summary, create a detailed visual prompt for a YouTube thumbnail.

        Create a detailed prompt for generating a thumbnail image that would attract viewers. Include:
            - Main visual elements
            - Color scheme
            - Text overlay suggestions
            - Overall composition

        Summary: {summary}
    """
    response = llm.invoke(prompt)

    thumbnail_prompt = response.content
    
    client = OpenAI()

    result = client.images.generate(
        model="gpt-image-1",
        prompt=thumbnail_prompt,
        quality="low",
        moderation="low",
        size="auto"
    )

    image_bytes = base64.b64decode(result.data[0].b64_json)

    filename = f"thumbnail_{concept_id}.jpg"

    with open(filename, "wb") as file:
        file.write(image_bytes)
    
    return {
        "thumbnail_prompts": [thumbnail_prompt],
        "thumbnail_sketches": [filename]
    }

def human_feedback(state: State):
    answer = interrupt({
        "chosen_thumbnail": "Which thumbnail do you like the most?",
        "feedback": "Provide any feedback or changes you'd like for the final thumbnail."
    })
    user_feedback = answer["user_feedback"]
    chosen_prompt = answer["chosen_prompt"]
    return {
        "user_feedback": user_feedback,
        "chosen_prompt": state["thumbnail_prompts"][chosen_prompt-1],
    }

def generate_hd_thumbnail(state: State):
    chosen_prompt = state["chosen_prompt"]
    user_feedback = state["user_feedback"]
    prompt = f"""
        You are a professional YouTube thumbnail designer. Take this original thumbnail prompt and create an enhanced version that incorporates the user's specific feedback.

        ORIGINAL PROMPT:
        {chosen_prompt}

        USER FEEDBACK TO INCORPORATE:
        {user_feedback}

        Create an enhanced prompt that:
            1. maintains the core concept from the original prompt
            2. Specifically addresses and implements the user's feedback request.
            3. Adds professional YouTube thumbnail specifications:
                - high contrast and bold visual elements
                - Clear focal points that draw the eye
                - Professional lighting and composition
                - Optimal text placement and readability with generous padding from edges
                - Colors that pop and grab attention
                - Elements that work well at small thumbnail sizes
                - IMPORTANT: Always ensure adequate white space/padding between any text and the image borders
    """

    response = llm.invoke(prompt)

    final_thumbnail_prompt = response.content
    
    client = OpenAI()

    result = client.images.generate(
        model="gpt-image-1",
        prompt=final_thumbnail_prompt,
        quality="high",
        moderation="low",
        size="auto"
    )

    image_bytes = base64.b64decode(result.data[0].b64_json)

    filename = f"thumbnail_final.jpg"

    with open(filename, "wb") as file:
        file.write(image_bytes)

# %%
graph_builder = StateGraph(State)

graph_builder.add_node("extract_audio", extract_audio)
graph_builder.add_node("transcribe_audio", transcribe_audio)
graph_builder.add_node("summarize_chunk", summarize_chunk)
graph_builder.add_node("mega_summary", mega_summary)
graph_builder.add_node("generate_thumbnails", generate_thumbnails)
graph_builder.add_node("human_feedback", human_feedback)
graph_builder.add_node("generate_hd_thumbnail", generate_hd_thumbnail)

graph_builder.add_edge(START, "extract_audio")
graph_builder.add_edge("extract_audio", "transcribe_audio")
graph_builder.add_conditional_edges("transcribe_audio", dispatch_summarizers, ["summarize_chunk"])
graph_builder.add_edge("summarize_chunk", "mega_summary")
graph_builder.add_conditional_edges("mega_summary", dispatch_artists, ["generate_thumbnails"])
graph_builder.add_edge("generate_thumbnails", "human_feedback")
graph_builder.add_edge("human_feedback", "generate_hd_thumbnail")
graph_builder.add_edge("generate_hd_thumbnail", END)

graph = graph_builder.compile(checkpointer=memory)

# %%
config = {
    "configurable": {
        "thread_id": 1
    },
}

# %%
graph.invoke(
    {"video_file": "interview.mp4"},
    config=config
)
# Out:
# {'video_file': 'interview.mp4',
#  'audio_file': 'interview.mp3',
#  'transcription': '서울 고려대학교 미역하에서 시작한 천 원짜리 영철 버거 핫도그 빵 사이에 고기 볶음과 양배추 소스 등을 넣은 버거는 큰 인기를 끌며 고려대의 명물이 됐습니다. 2000년 영철 버거를 상업한 이영철 씨는 2004년부터 고려대학교에 매년 2천만 원을 기부했습니다. 학생들의 주머니 사정을 생각해 적자에도 천 원의 약속을 지켰습니다. 2015년엔 결국 경영난으로 폐업했는데 고려대 동문들이 나서 가게를 일으켜 세우며 화제가 되기도 했습니다. 10년 전 JTBC와의 인터뷰에서는 재개업을 앞둤던 이 씨의 두려움과 설렘이 고스란히 담겨 있었습니다. 기분이야 뭐 정말 새롭죠. 많이 걱정도 되고 두렵기도 하고 고맙기도 하고 앞으로 성장하고 있으면 어떻게 하실 거예요? 소심으로 돌아가서 열심히 일하고 또 학생들하고 많이 소통하고 하려고 합니다. 이 씨는 인터뷰 내내 미소를 지었습니다. 너무너무 감사하고 정말 그 고마움 잊지 않고 내가 살아가는 모습으로 보답하려고 해요. 암투병 중이던 이 씨는 지난 13일 18살의 나이로 세상을 떠났습니다. 빈손은 이 씨의 평생일도 고려대학교 안암병원 장례식장에 마련됐습니다. 외롭고 방황하던 청춘의 허기진 마음들을 이불처럼 덮어주셨던 사장님의 삶을 생기겠다 웃음이 눈가에 발자국 남는 사람이 되어 기억하겠다. 온라인 후보에는 1,000개 넘는 추모와 추억의 메시지가 속속 담겨지고 있습니다. 이 씨의 발의는 내일 이뤄집니다.\n',
#  'summaries': ['[Chunk 1] - 서울 고려대학교에서 큰 인기를 끈 천 원짜리 영철 버거 핫도그는 빵 사이에 고기 볶음과 양배추 소스를 넣은 고유의 메뉴로 명물이 됐다.\n- 이영철 씨가 이 버거를 2000년에 상업화했고, 2004년부터 매년 2천만 원을 고려대에 기부했다. 학생들의 주머니 사정을 고려해 천 원 가격 약속을 지켰다.\n- 2015년 경영난으로 가게가 폐업했지만, 고려대 동문들이 가게를 다시 일으켜 세우며 화제가 됐다.\n- 약 10년 전 JTBC와의 인터뷰에서 재개업을 앞둔 이 씨의 두려움과 설렘이 드러났고, “새롭다, 걱정과 두려움도 있지만 감사하다”는 마음으로 학생들과 소통하고 열심히 일하겠다고 다짐했다. 인터뷰 내내 미소를 보였으며, 살아가며 보답하겠다고 강조했다.\n- 당시에 이 씨는 암투병 중이었다는 내용도 함께 남아 있다.',
#   '[Chunk 2] - 18세의 이 씨가 13일 세상을 떠났고, 장례식은 고려대 안암병원 장례식장에서 치러진다.\n- 이 씨의 평생일도가 마련되었고, 외롭고 방황하던 청춘의 마음을 보듬어 준 사장님의 삶을 기억하겠다는 다짐이 남아 있다.\n- 온라인에는 1,000건이 넘는 추모와 추억의 글이 속속 올라오고 있다.\n- 이 씨의 발의(장례식)은 내일 이뤄진다.'],
#  'thumbnail_prompts': ['Here is a detailed visual prompt you can use to generate a YouTube thumbnail that fits the summary:\n\n- Main visual elements\n  - A cinematic two-panel collage with a diagonal divider, left side warm and inviting, right side somber and reflective.\n  - Left panel: close-up, tasteful depiction of a 1,000-won burger-hotdog hybrid on a plate with shredded cabbage sauce. Include a small, discreet price tag reading “1000원.” Warm, golden lighting (sunset tones) to convey nostalgia and positive memory.\n  - Background on left: blurred campus scene suggesting Korea University (distinctive campus architecture or gate silhouette) with bokeh and an orange glow.\n  - Subtle foreground detail: a respectful, shadowy silhouette or outline hinting at a founder’s contribution (이지영철/이영철 name can be implied as a legacy) without showing an identifiable portrait; convey dignity and gratitude.\n  - Right panel: a quiet memorial scene. Soft candlelight, white lilies, and a faint, respectful silhouette of a young person to imply the 18-year-old’s remembrance. The background should be cooler (blues/purples) with a gentle, dim campus ambiance.\n  - Optional small iconography: a tiny microphone or “news” motif to hint at the JTBC interview, placed unobtrusively (e.g., upper corner) so the main focus stays on the story.\n  - Overall mood: contrast between warmth (past generosity) and somber memorial (loss), yet kept respectful and uplifting in tone.\n\n- Color scheme\n  - Left side: warm yellows/oranges/golds (e.g., amber, #FFB347; gold, #FFD166; cream).\n  - Right side: cool blues/purples (e.g., navy #1A2A4A, indigo #2C3A87, soft lavender #A29BFF).\n  - Diagonal divider blended with a subtle gradient from warm to cool to emphasize the transition from giving to remembrance.\n  - Text should be bright and highly legible: white with a thin dark outline or drop shadow; consider a warm accent color (gold) for emphasis on one word.\n\n- Text overlay suggestions\n  - Style: bold, clean sans-serif Korean font; high contrast; 2-line main title with a short subtitle. Ensure safe area margins so text isn’t cut off on small screens.\n  - Option A (strong, editorial): \n    - Line 1: 고려대 1000원 버거의 기적\n    - Line 2: 헌신과 추모의 이야기\n  - Option B (concise, high intrigue):\n    - Line 1: 1000원 버거의 이야기\n    - Line 2: 기여와 비극의 교차\n  - Option C (mobile-friendly):\n    - Line 1: 한 끼가 남긴 이야기\n    - Line 2: 헌신 vs 비극\n  - Text styling tips: bold, high-contrast white text; optional gold accent for the keyword 버거 or 기적; incorporate a thin black or dark gray outline for readability; keep font size large enough to read on mobile thumbnails.\n\n- Overall composition\n  - Aspect ratio: 16:9 (optimal for YouTube thumbnails). Target resolution suggestions: 1920x1080 or at least 1280x720.\n  - Composition rules: use the diagonal split to guide the viewer’s eye from the warm left to the cool right; keep the main burger image and memorial elements near the respective panel centers.\n  - Depth and lighting: soft cinematic lighting with slight vignetting to focus attention on the center divider; subtle lens flare on the warm left to evoke nostalgia.\n  - Readability: ensure the main title sits in a clear space above or along the divider, not over busy details; keep secondary subtitle smaller and below the main title.\n  - Accessibility: high color contrast, avoid relying solely on color to convey meaning (use shape, icons, and layout to support the message).\n\n- Style/tone guidance for generation\n  - Realistic yet slightly stylized (photorealistic with painterly edges) to feel documentary and respectful.\n  - Cinematic, story-driven mood rather than flashy sensationalism.\n  - Respectful depiction of memorial imagery; no graphic or distressing visuals. Keep it uplifting and commemorative.\n\nIf you’d like, I can tailor this to a specific image generation model (e.g., Stable Diffusion, Midjourney, or DALL-E) by converting it into a single, model-ready prompt with prec ...
#   '다음은 이 영상 요약을 바탕으로 제작할 수 있는 유튜브 썸네일용 상세 프롬프트입니다. 이미지를 생성하는 모델에 바로 투입하거나, 디자이너에게 전달하기 좋도록 구성했습니다.\n\n1) 핵심 컨셉\n- 좌측의 주인공 요소: 고려대에서 큰 인기를 끌었던 1,000원 버거를 클로즈업으로 실감나게 표현. 고기 볶음과 양배추 소스가 빵 사이에 든 모습이 선명하게 보이도록.\n- 우측의 추모/기억 요소: 이영철 씨의 인생과 헌신을 존중하는 분위기로, 촛불, 꽃, 조용한 분위기의 묵념 느낌(그레이 스케일 또는 아주 차분한 채도)으로 표현.\n- 중앙부의 다리 역할: 두 이야기를 잇는 다리 역할로, 미묘한 빛줄기나 얇은 수직 구분선을 넣어 연결감을 줌.\n- 추가 요소: JTBC 인터뷰를 연상시키는 마이크 아이콘이나 방송 로고의 작은 배치, 그리고 "추모"나 "기부"를 상징하는 작은 심장/리본 아이콘.\n\n2) 메인 시각 요소\n- 왼쪽: 1000원 버거의 고퀄리티 클로즈업 샷. 빵의 질감, 고기 볶음의 윤기, 양배추 소스의 색감이 강조되도록 촬영 가능하면 부드러운 조명. 버거 옆에 작은 가격 태그 “1000원”을 시각적으로 강조.\n- 오른쪽: 촛불, 꽃다발, 메모리 카드 등이 어두운 배경에서 편안하게 보이도록 배치. 너무 자극적이지 않도록 흐릿하게 포커스 맞춤(배경 흐림)으로 처리.\n- 중앙/배경: 고려대 캠퍼스 실루엣이나 벽돌 벽 등 학교 분위기를 암시하는 배경 요소를 아주 흐리게 배치하여 맥락을 전달.\n\n3) 색상 팔레트\n- 주조색(버거 측): 따뜻한 골든 브라운, 오렌지, 레드 톤으로 식욕 자극 및 따뜻함 표현.\n- 추모 측: 차분한 블루-그레이 계열, 차분한 채도, 다크 그레이와 네이비 계열로 존중감 강조.\n- 포인트/강조: 금색이나 옐로우 골드로 하이라이트를 주고, 텍스트 가장자리에는 검은색 테가 있어 가독성 강화.\n- 전체 분위기: 따뜻함과 차분함이 균형 잡힌 “감성적 다큐멘터리 포스터” 느낌.\n\n4) 텍스트 오버레이 제안 (추천 문구)\n- 메인 타이틀(가장 눈에 띄는 위치에, 큰 글씨)\n  - "고려대 1,000원 버거의 기적과 헌신"\n  - "버거로 시작한 기부, 남겨진 이야기"\n- 서브 타이틀(좀 더 작은 글씨, 보조 설명)\n  - "이영철의 삶과 추모의 흐름"\n  - "JTBC 인터뷰로 본 그의 마음"\n- 티저/뱃지 스타일 소형 텍스트\n  - "인터뷰 보도" / "추모" / "재개 소식" 같은 라벨\n- 예시 텍스트 배치 아이디어\n  - 상단 중앙: "고려대 1,000원 버거의 기적과 헌신"\n  - 하단 중앙: "이영철의 이야기 • 추모와 기억"\n  - 좌하단 작은 라벨: "JTBC 인터뷰 보도" (작고 선명한 배지형)\n- 영어 버전 옵션도 필요하면 추가 가능\n  - "The 1000-Won Burger: Heritage, Hope, and Loss"\n\n5) 전반적 구성 가이드\n- 레이아웃: 16:9 비율의 썸네일이므로 좌-버거, 우-추모의 이원 구도로 구성하되 중앙에 가볍게 연결감을 주는 디바이더(두께가 얇은 빛줄기나 그림자)를 넣기.\n- 텍스트 가독성: 배경이 복잡하지 않도록 텍스트 영역에 반투명 어두운 오버레이를 두고, 흰색 폰트에 검은 테두리(또는 그림자)로 고대비를 생성.\n- 포맷: 1280x720 픽셀, 300dpi(가능한 경우), PNG 또는 고해상도 JPEG.\n- 스타일 톤: 리얼리티 기반 포토그래피+포스터 느낌의 합성(collage) 스타일. 과장된 연출보단 따뜻하고 존중하는 분위기 중심.\n- 분위기 주의사항: 이슈가 민감한 사망 소식도 포함하므로, 자극적이거나 선정적인 표현은 피하고 존중과 애도를 담아 표현.\n\n6) 제작용 구체 프롬프트 예시 (복사해 바로 사용 가능)\n- 프롬프트(영문 예시, 이미지 생성 모델에 바로 투입 가능):\n  "Create a photorealistic YouTube thumbnail, 1280x720, 16:9. A split-composite poster: on the left, a close-up shot of a famous 1000-won burger with juicy fried meat and cabbage sauce, warm golden lighting; behind it a soft silhouette of Korea University campus. On the right, a quiet memorial scene with candles, flowers, and a subtle handwritten note, in cool muted blues and grays. A thin vertical divider with soft glow links the two sides. Include a small JTBC interview microphone icon subtly in the upper middle. Text overlays in bold white with black outline: main title \'고려대 1,000원 버거의 기적과 헌신\' and subtitle \'이영철의 삶과 추모의 흐름\'. Optional badge: \'JTBC 인터뷰 보도\'. Overall mood: respectful, nostalgic, hopeful. Color palette: warm amber/brown on burger side; desaturated blues/greys on memorial side; gold accent for highlights. Realistic textures, slight film grain for cohesion. Ensure high readability of text at small sizes."\n- 한글 버전 준비용 프롬프트:\n  "썸네일용 포토리얼티크 이미지 생성. 해상도 1280x720, 16:9. 좌측에 유명한 1,000원 버거의 클로즈업 샷을 따뜻한 골든 조명으로, 버거의 고기 볶음과 양배추 소스가 선명하게 보이도록; 배경에 고려대 캠퍼스 실루엣을 흐릿하게 배치. 우측에는 촛불과 꽃, 조용한 추모 분위기의 이미지(차분한 파란-회색 계통)로 구성. 두 영역을 연결하는 얇은 빛줄기/그림자로 경계 주기. 중앙 상단에는 JTBC 인터뷰 마이크 아이콘을 작게 배치. 텍스트 오버레이: 큰 글씨 \'고려대 1,000원 버거의 기적과 헌신\', 보조 글씨 \'이영철의 삶과 추모의 흐름\'. 라벨형 소형 텍스트 \'JTBC 인터뷰 보도\'. 톤은 존중과 애도를 담되, 이미지 전체는 따뜻함과 희망을 병행. 색상 팔레트: 버거 쪽은 따뜻한 골든 브라운, 추모 쪽은 차분한 블루-그레이, 포인트로 금색 하이라이트. 텍스트는 흰색-검정 그림자 조합으로 가독성 확보. 사진 질감은 약간의 필름 그레인 added for cohesion."\n\n필요하신 경우 이 프롬프트를 조정해 드리겠습니다.\n- 원하시는 분위기(더 밝거나 더 묵직한 분위기, 더 모던한 느낌 등)나 특정 채널 스타일(채널 로고 색상, 폰트 스타일) 반영도 가능합니다.\n- 텍스트 overlay를 더 많이/덜 넣고 싶으신지, 글자 수를 몇 줄로 제한할지 등도 알려주시면 구체적으로 다듬어 드리겠습니다.',
#   '다음은 이 요약을 바탕으로 유튜브 썸네일을 만들기 위한 자세한 시각적 프롬프트입니다. 한 화면에 두 이야기를 강하게 대비시키되, 시각적으로 매력적이고 읽기 쉬운 구성을 제안합니다.\n\n핵심 컨셉\n- 고려대 커뮤니티의 전설적인 1,000원 버거 이야기와 동시에 벌어진 추모의 이야기 두 가지를 한 화면에 담아, 감정의 흐름(희망/헌신 → 비극과 기억)을 느끼게 하는 썸네일.\n\n주요 시각 요소 (Main visual elements)\n- 레이아웃: 좌우 대칭이 아닌 다이내믹한 분할(대각선 또는 수직 분할)로 두 스토리를 구분하되 전체적으로 하나의 화면처럼 보이도록 구성.\n- 좌측 패널(명물 이야기):\n  - 고려대학교 캠퍼스의 생동감 있는 배경(푸릇한 잔디, 교정 건물의 실루엣).\n  - 전면에 1,000원 버거 핫도그를 돋보이게 배치. 빵 사이의 볶음고기+양배추 소스가 보이는 스트리트푸드 느낌으로 사실감 강조.\n  - 작은 아이콘이나 배지로 창시자 이영철의 이름(이영철)과 “2000년 commercialized” 같은 연대를 암시하는 요소.\n  - 밝은 조명, 따뜻한 색감(황금빛/노란빛)으로 활력과 생동감 강조.\n- 우측 패널(추모 이야기):\n  - 촛불과 꽃으로 구성된 추모 분위기. 흐릿한 실루엣의 청년(또는 고즈넉한 분위기의 어른 그림자)을 배경으로 배치해 구체 인물 대신 상징으로 표현.\n  - 병원/장례식장 분위기를 연상시키는 은은한 배경, 차분한 파란계열과 회색 톤으로 침착한 분위기 조성.\n  - 촛불의 따뜻한 주황빛이 어두운 쪽과의 대비를 이루도록 배치.\n  - JTBC 인터뷰를 암시하는 작은 마이크 아이콘이나 로고를 모서리 하나에 작게 배치(출처를 암시하되 과도하게 강조하지 않음).\n- 텍스트 요소(텍스트 오버레이는 스토리의 핵심 메시지를 전달하는 데 필수):\n  - 메인 타이틀은 화면 상단 중앙 또는 양측 경계 근처에 크게 배치.\n  - 보조 문구는 메인 타이틀 하단이나 하단 영역에 얹되, 두 줄 정도로 제한.\n  - 폰트는 두께가 굵고 가독성이 높은 산세리프 계열(예: Sans-serif 계열). 텍스트에 그림자나 억센 outline를 주어 배경과 충분히 구분되도록.\n\n색상 팔레트 (Color scheme)\n- 좌측: 활기찬 초록/진한 녹색 계열 + 황금빛 포인트. 버거의 노릇노릇한 색감과 대학 캠퍼스의 생동감을 강조.\n- 우측: 차분한 블루-그레이 톤, 촛불의 따뜻한 주황빛(오렌지/골드)으로 포인트를 줌.\n- 전체 톤: 좌우의 대비가 선명하되 전체적으로는 따뜻하고 정서적인 분위기로 연결되도록 그라데이션이나 라이트링으로 연결.\n\n텍스트 오버레이 제안 (Text overlay ideas)\n- 오리지널 프롬프트에서 채택 가능한 4가지 옵션\n  1) Option A: "고려대 1,000원 버거의 전설" / 보조문구: "창시자 이영철의 헌신과 추모의 이야기"\n  2) Option B: "1,000원 버거, 두 이야기의 기억" / 보조문구: "헌신과 비극이 남긴 유산"\n  3) Option C: "고려대 커뮤니티의 기억, 버거와 추모" / 보조문구: "암투병 속 인터뷰와 추모의 물결"\n  4) Option D: "전설은 끝나지 않았다: 버거의 기부와 추모" / 보조문구: "JTBC 인터뷰 속 용기와 남겨진 기억"\n- 스타일 팁:\n  - 메인 타이틀은 굵고 굵은 산세리프체(두께감 있게). 가능하면 그림자+황금빛 테두리로 대비 강화.\n  - 보조 텍스트는 메인보다 작은 크기로 배치하되, 같은 폰트 패밀리에서 굵기 차이로 계층감 주기.\n  - 배경과의 대비를 위해 흰색/노란색 계열 텍스트에 검은 색 그림자 혹은 얇은 검은 테두리 주기.\n  - 텍스트 길이를 짧고 강하게 유지하기. 한 줄짜리 큰 문구 1개 + 보조 문구 1개 정도가 적합.\n\n구성 및 사진/그래픽 스타일 가이드\n- 가이드라인:\n  - 해상도/비율: 16:9, 1280x720 혹은 1920x1080 픽셀.\n  - 포커스: 좌측의 버거+캠퍼스가 초점, 우측의 추모 요소가 약간 흐리게 배치되되 깊이감을 주기 위해 얕은 피사계 심도로 처리.\n  - 조명: 좌측은 밝고 생동감 있는 조명, 우측은 촛불빛과 차가운 배경의 대비로 분위기 차이를 극대화.\n  색상 대비를 통해 두 이야기가 화면에서 자연스럽게 연결되도록 경계부에 약간의 빛 번짐이나 미세한 글로우를 추가.\n- 그래픽 스타일 옵션:\n  - 사진 실사 톤 또는 사실적인 일러스트 스타일 모두 가능. 단, 너무 디테일하게 과하게 묘사하기보다 아이콘형 요소(마이크 아이콘, 1,000원 태그, 촛불 아이콘 등)를 포함해 텍스트 가독성을 유지.\n  - 가볍게 비네트(테두리 어둡게) 처리로 영상의 중앙으로 시선을 유도.\n\n생성용 프롬프트 예시 (AI 이미지 생성 모델용)\n- 기본 프롬프트(한국어 요약 포함):\n  - "16:9 YouTube thumbnail, split-screen style. Left half: vibrant Korea University campus background with a prominent 1,000-won burger hotdog in the foreground; warm golden-yellow lighting, lively atmosphere, small badge with the name \'이영철\' and a coin motif; right half: somber memorial scene with candles and flowers, muted blue-gray tones, soft-focus silhouette of a young man to imply memory and loss, subtle JTBC microphone icon in the corner; main title across the top: \'고려대 1,000원 버거의 전설\', secondary line: \'창시자 이영철의 헌신과 추모의 이야기\'; bold, high-contrast typography with white/yellow text and light black shadow; cinematic, high saturation on left, desaturated on right, slight film grain, gentle vignette; ensure readability at small sizes."\n- 세부 옵션(선택적으로 추가 가능):\n  - 텍스트 위치: 상단 중앙에 메인 타이틀, 하단 좌우에 보조문구.\n  - 스타일: 포토리얼리스틱 또는 일러스트릭(현실감 강조) 중 선택.\n  - 아이콘/로고: JTBC 마이크 아이콘은 작게 모서리에 배치.\n  - 질감 및 효과: 약간의 HDR 느낌, 색 보정으로 좌우 명암 대비 강화.\n\n추가 고려사항\n- 실제 인물 사진 사용이 필요 없는 방식으로 구성하되, 이름과 핵심 사건은 텍스트로 명시해 이해를 돕도록 합니다.\n- 썸네일의 텍스트는 작은 화면에서도 읽히기 쉽도록 충분한 여백과 강한 대비를 유지합니다.\n- 로고나 저작권이 민감할 수 있는 실사 이미지 사용은 피하고, 스타일리시한 일러스트/그래픽 요소로 대체하는 것을 권장합니다.\n\n필요하시면 위 프롬프트를 특정 생성 도구(Midjourney/Stable Diffusion 등)에 맞춘 정확한 문법 버전으로 변환해 드릴게요. 원하는 스타일(사진 실사 vs 일러스트), 그리고 톤(더 진지하게 vs 더 다이내믹하게)을 알려주시면 맞춤으로 다듯째 드리겠습니다.'],
#  'thumbnail_sketches': ['thumbnail_1.jpg',
#   'thumbnail_2.jpg',
#   'thumbnail_3.jpg'],
#  'final_summary': '다음은 두 기사 내용을 하나로 엮은 종합 요약이다.\n\n- 고려대 천 원짜리 영철 버거 핫도그 이야기\n  - 서울의 고려대학교에서 큰 인기를 끈 이 버거는 고기 볶음과 양배추 소스를 빵 사이에 넣은 독특한 구성으로 명물이 됐다. 창시자는 이영철 씨로 전해지며, 2000년에 상업화했고 2004년부터 매년 2천만 원을 고려대에 기부해 학생들의 부담을 덜어주려 애썼다. 가격은 1,000원으로 고정해 학생들의 주머니를 배려했다.\n  - 2015년 경영난으로 가게가 폐업했지만, 고려대 동문들이 다시 가게를 살려 화제가 됐다.\n  - 재개를 앞두고 JTBC와의 인터뷰가 보도되었는데, 이영철 씨는 두려움과 설렘이 공존하는 마음을 드러내며 학생들과의 소통과 열심히 일하겠다는 다짐을 밝혔다. 인터뷰 내내 미소를 잃지 않았고, 살아가며 보답하겠다는 마음을 강조했다. 다만 암투병 중이었다는 사실도 함께 전달됐다.\n\n- 이씨의 사망 및 추모 소식\n  - 또 다른 보도에 따르면 이씨로 알려진 사람이 18세의 나이에 13일 세상을 떠났고, 장례식은 고려대 안암병원 장례식장에서 치러졌다.\n  - 그의 삶의 여정은 외롭고 방황하던 청춘의 마음을 보듬었다는 평가가 남아 있으며, 온라인에는 1,000건이 넘는 추모와 추억의 글이 올라왔다.\n  - 발인은 내일로 예고되었으며, 그의 생애와 함께 남긴 기록들이 이후에도 기억될 예정이다.\n\n종합적으로, 이 이야기는 고려대 커뮤니티에 깊이 남은 한 사람의 사회적 기여와 헌신, 그리고 또 다른 이의 비극적 상실과 그에 대한 애도의 흐름을 함께 보여준다.',
#  '__interrupt__': [Interrupt(value={'chosen_thumbnail': 'Which thumbnail do you like the most?', 'feedback': "Provide any feedback or changes you'd like for the final thumbnail."}, id='ac15f8d3fb2a3a026ba210f431523292')]}

# %%
response = {
    "user_feedback": "Make sure the mood of the thumbnail not much sad. and give it a photo realistic, 3d style.",
    "chosen_prompt": 1,
}
# Out:
# ('human_feedback',)

# %%
graph.invoke(
    Command(resume=response),
    config=config
)
